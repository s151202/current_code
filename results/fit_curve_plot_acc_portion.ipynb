# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
x = [30,40, 50,70,100]
y = [50,55, 75,89,90]

z = np.polyfit(x,y,2)
p = np.poly1d(z)

x_plot = np.arange(30,105,1)
plt.plot(x_plot, p(x_plot) ,'b--')
plt.plot(x,y, 'ro')

# %% [markdown]
# # evaluation results

# %%
s1_gs_100 = []
s1_gs_70 = []
s1_gs_50 = []
s1_gs_30 = []
s1_gs_10 = []

# %% [markdown]
# ## gold stand

# %%
#subject percentage for portion of 100%, 70%, 50%, 30% and 10% of all training data
A1_p_gs = [88.24, 82.91, 83.33, 66.47, 55.71 ]
A2_p_gs = [61.32, 58.76, 56.51, 48.64, 36.32 ]
A3_p_gs = [87.08, 84.87, 87.08, 73.82, 35.26 ]
A4_p_gs = [65.51, 55.37, 50.25, 47.66, 30.86 ]
A5_p_gs = [58.07, 59.72, 44.68, 36.97, 29.96 ]
A6_p_gs = [51.56, 48.31, 39.3, 37.88, 32.94 ]
A7_p_gs = [89.95, 87.79, 81.5, 74.19, 48.46 ]
A8_p_gs = [84.53, 85.62, 84.14, 75.3, 58.24 ]
A9_p_gs = [77.26, 80.42, 76.83, 66.08, 42.79 ]

#subject kappa value for portion of 100%, 70%, 50%, 30% and 10% of all training data
A1_k_gs = [0.843,0.772,0.777,0.554,0.411]
A2_k_gs = [0.482,0.448,0.416,0.312,0.149]
A3_k_gs = [0.829,0.8,0.829,0.653,0.136]
A4_k_gs = [0.538,0.399,0.329,0.298,0.074]
A5_k_gs = [0.435,0.456,0.256,0.156,0.064]
A6_k_gs = [0.355,0.311,0.189,0.17,0.106]
A7_k_gs = [0.865,0.836,0.75,0.654,0.308]
A8_k_gs = [0.793,0.808,0.788,0.67,0.44]
A9_k_gs = [0.697,0.737,0.692,0.549,0.239]


GS_p = [A1_p_gs,A2_p_gs,A3_p_gs,A4_p_gs,A5_p_gs,A6_p_gs,A7_p_gs,A8_p_gs,A9_p_gs]
GS_k = [A1_k_gs,A2_k_gs,A3_k_gs,A4_k_gs,A5_k_gs,A6_k_gs,A7_k_gs,A8_k_gs,A9_k_gs]

# %% [markdown]
# ## TL - kld

# %%
#subject percentage for portion of 100%, 70%, 50%, 30% and 10% of all training data
A1_p_kld = [87.85 , 84.05 , 83.29 , 69.03 , 60.57  ]
A2_p_kld = [63.07 , 52.48 , 52.14 , 54.26 , 40.2 ]
A3_p_kld = [86.66 , 80.39 , 83.02 , 78.17, 42.52 ]
A4_p_kld = [67.7 , 59.56 , 49.52 , 46.7, 36.22 ]
A5_p_kld = [58.2 , 55.49 , 47.88 , 38.01,26.52 ]
A6_p_kld = [53.07 , 43.39 , 41.92 , 41.17,  24.95 ]
A7_p_kld = [87.9 , 88.5 , 83.79 , 79.35, 45.3 ]
A8_p_kld = [88.96 , 83.0 ,  83.78, 72.95,55.75 ]
A9_p_kld = [84.41 , 83.64 , 75.38, 66.39, 50.82 ]

#subject kappa value for portion of 100%, 70%, 50%, 30% and 10% of all training data
A1_k_kld = [0.839,0.787, 0.777, 0.587, 0.474]
A2_k_kld = [0.505,0.364, 0.359, 0.388, 0.2]
A3_k_kld = [0.824,0.741, 0.775, 0.711, 0.234]
A4_k_kld = [0.568,0.457, 0.317, 0.284, 0.151]
A5_k_kld = [0.433,0.396, 0.295, 0.167, 0.02]
A6_k_kld = [0.374,0.244, 0.225, 0.214, 0.0]
A7_k_kld = [0.837,0.846, 0.783, 0.722,0.267]
A8_k_kld = [0.852,0.774, 0.783, 0.64, 0.409]
A9_k_kld = [0.793,0.783, 0.672, 0.551, 0.344]


KLD_p = [A1_p_kld,A2_p_kld,A3_p_kld,A4_p_kld,A5_p_kld,A6_p_kld,A7_p_kld,A8_p_kld,A9_p_kld]
KLD_k = [A1_k_kld,A2_k_kld,A3_k_kld,A4_k_kld,A5_k_kld,A6_k_kld,A7_k_kld,A8_k_kld,A9_k_kld]

# %% [markdown]
# ## TL - mi

# %%
#subject percentage for portion of 100%, 70%, 50%, 30% and 10% of all training data
A1_p_mi = [87.49  ,  82.95  , 82.95 , 77.22  ,55.68   ]
A2_p_mi = [65.56 , 56.74  , 48.66 , 52.81 , 39.33  ]
A3_p_mi = [82.24  , 80.02 , 84.1 , 75.25, 39.49 ]
A4_p_mi = [68.1  ,  66.67 , 52.38 , 48.21, 30.58 ]
A5_p_mi = [56.36  , 46.48 , 44.89 , 41.96,31.24 ]
A6_p_mi= [51.28  , 49.78 , 37.43 , 43.09 ,  35.74 ]
A7_p_mi = [89.3  , 90.28 , 87.05 ,  69.99, 53.87  ]
A8_p_mi = [87.13  , 85.26 ,  85.23, 76.61, 62.54 ]
A9_p_mi = [82.21  , 79.88 , 69.88, 65.76, 43.36 ]

#subject kappa value for portion of 100%, 70%, 50%, 30% and 10% of all training data
A1_k_mi = [0.834,0.772, 0.772, 0.696,0.411]
A2_k_mi = [0.538,0.421, 0.312, 0.369,0.19]
A3_k_mi = [0.765,0.736, 0.79, 0.672, 0.194]
A4_k_mi = [0.573,0.55, 0.359, 0.304,0.072]
A5_k_mi = [0.409,0.277, 0.257, 0.225, 0.08]
A6_k_mi = [0.35,0.33, 0.165, 0.239, 0.141]
A7_k_mi = [0.856,0.87, 0.827, 0.597,0.381]
A8_k_mi = [0.828,0.803, 0.803, 0.69, 0.498]
A9_k_mi = [0.763,0.732, 0.596, 0.541, 0.244]


MI_p = [A1_p_mi,A2_p_mi,A3_p_mi,A4_p_mi,A5_p_mi,A6_p_mi,A7_p_mi,A8_p_mi,A9_p_mi]
MI_k = [A1_k_mi,A2_k_mi,A3_k_mi,A4_k_mi,A5_k_mi,A6_k_mi,A7_k_mi,A8_k_mi,A9_k_mi]

# %%
def fit_curve (y, order = 3, portion = portion):
    z = np.polyfit(portion,y,order)
    p = np.poly1d(z)
    return p

# %%
to_save = 1



portion = [10,30, 50,70,100]

for s in range (0,9):

    y_gs_k = GS_k[s][::-1]
    y_kld_k = KLD_k[s][::-1]
    y_mi_k = MI_k[s][::-1]
    y_gs_p = GS_p[s][::-1]
    y_kld_p = KLD_p[s][::-1]
    y_mi_p = MI_p[s][::-1]
    
    if s == 3-1 or s == 5-1:
        order = 2
    else:
        order = 3
    order =3
    p_gs_k = fit_curve(y_gs_k, order)
    p_gs_p = fit_curve(y_gs_p, order)
    p_kld_k = fit_curve(y_kld_k, order)
    p_kld_p = fit_curve(y_kld_p, order)
    p_mi_k = fit_curve(y_mi_k, order)
    p_mi_p = fit_curve(y_mi_p, order)
    


    x_plot = np.arange(10,100,1)
    #plt.plot(x_plot, p_gs_k(x_plot) ,'r--', linewidth=1.2)
    #plt.plot(x_plot, p_kld_k(x_plot) ,'b--', linewidth=1.2)
    #plt.plot(x_plot, p_mi_k(x_plot) ,'g--', linewidth=1.2)
    plt.plot(portion,y_gs_p, 'ro', markersize=7)
    plt.plot(portion,y_kld_p, 'b^', markersize=7)
    plt.plot(portion,y_mi_p, 'gv',markersize=7)
    plt.xticks([10,30,50,70,100], fontsize = 16)
    plt.yticks(fontsize = 16)

    

    if to_save == 1:
        plt.savefig('D:\\Diamond\\pics\\current_results\\tl\\no_fit_curve' + str(s+1) + '_p.png', dpi = 800)
    plt.show()

# %%
plt.hlines(25, 0,10,'r', linestyles='dashed',linewidth=2)
plt.hlines(15, 0,10,'r', linestyles='dashed',linewidth=2)
plt.hlines(10, 0,10,'b', linestyles='dashed',linewidth=2)
plt.hlines(5, 0,10,'g', linestyles='dashed',linewidth=2)
plt.hlines(-5, 0,10,'g', linestyles='dashed',linewidth=2)
plt.plot(4,5, 'gv', markersize=7)
plt.plot(4,10, 'b^', markersize=7)
plt.plot(4,15, 'ro', markersize=7)
plt.savefig('D:\\Diamond\\pics\\current_results\\tl\\' + 'legend.png', dpi = 800)

# %%
A1_p[::-1]
# Out:
# [55.71, 66.47, 83.33, 82.91, 88.24]

# %%
A1_p
# Out:
# [88.24, 82.91, 83.33, 66.47, 55.71]

# %% [markdown]
# # Stats analysis

# %%
GS_k = np.array(GS_k)
GS_p = np.array(GS_p)
KLD_k = np.array(KLD_k)
KLD_p = np.array(KLD_p)
MI_k = np.array(MI_k)
MI_p = np.array(MI_p)
# Out:
# (9, 5)

# %%
a = GS_k
b = KLD_k

scipy.stats.wilcoxon(a,b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-ff496510eb64> in <module>
#       2 b = KLD_k
#       3
# ----> 4 scipy.stats.wilcoxon(a,b)
#
# AttributeError: module 'scipy' has no attribute 'stats'

# %%
pt = 4
GS_k[:,pt], KLD_k[:,pt], MI_k[:,pt]
# Out:
# (array([0.411, 0.149, 0.136, 0.074, 0.064, 0.106, 0.308, 0.44 , 0.239]),
#  array([0.474, 0.2  , 0.234, 0.151, 0.02 , 0.   , 0.267, 0.409, 0.344]),
#  array([0.411, 0.19 , 0.194, 0.072, 0.08 , 0.141, 0.381, 0.498, 0.244]))

# %%
GS_p[:,pt], KLD_p[:,pt], MI_p[:,pt]
# Out:
# (array([55.71, 36.32, 35.26, 30.86, 29.96, 32.94, 48.46, 58.24, 42.79]),
#  array([60.57, 40.2 , 42.52, 36.22, 26.52, 24.95, 45.3 , 55.75, 50.82]),
#  array([55.68, 39.33, 39.49, 30.58, 31.24, 35.74, 53.87, 62.54, 43.36]))
